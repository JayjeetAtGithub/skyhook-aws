# %%
import os
import json
import numpy as np

import matplotlib.pyplot as plt

# %%
def clean_string(path):
    path = path.replace(".", "_")
    path = path.replace("/", "_")
    return path

def plot(path, line_colors, param, param_title):
    results = {
        'write_data': None,
        'seq_data': None,
        'rand_data': None
    }
    filenames = [
        os.path.join(path, "write.json"),
        os.path.join(path, "seq.json"),
        os.path.join(path, "rand.json")
    ]
    for filename, line_color in zip(filenames, line_colors):
        with open(filename, 'r') as f:
            results[f'{filename[:-5]}_data'] = json.loads(f.read())['datas']  

        x = list()
        y = list()
        for itr in results[f'{filename[:-5]}_data']:
            x.append(int(itr['sec']))
            y.append(float(itr[param]))
            
        plt.plot(x[:-1], y[:-1], markersize=10, linewidth=3.0, color=line_color)

    plt.legend(['Write', 'Sequential read', 'Random read'])
    plt.xlabel('Time (s)')
    plt.xlim(0, 180)
    plt.ylabel(f"{param_title}")
    path = clean_string(path)
    plt.title(f"radosbench_metal - {path}")
    plt.savefig(f"radosbench_metal_{path}.pdf", bbox='tight')
    plt.show()
    plt.cla()
    plt.clf()

# %%
results='../../results/radosbench_metal'

# %%
for num_osd in os.listdir(results):
    for object_size in os.listdir(os.path.join(results, num_osd)):
        data_path = os.path.join(results, num_osd, object_size)
        plot(data_path, ['red', 'blue', 'green'], 'cur_bw', 'Throughput (MB/s)')
# Out:
# /var/folders/v6/yf2_m27929b9ms5vf1k6vvpw0000gn/T/ipykernel_16119/3566550557.py:35: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "bbox" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(f"radosbench_metal_{path}.pdf", bbox='tight')
# /var/folders/v6/yf2_m27929b9ms5vf1k6vvpw0000gn/T/ipykernel_16119/3566550557.py:35: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "bbox" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(f"radosbench_metal_{path}.pdf", bbox='tight')
# /var/folders/v6/yf2_m27929b9ms5vf1k6vvpw0000gn/T/ipykernel_16119/3566550557.py:35: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "bbox" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(f"radosbench_metal_{path}.pdf", bbox='tight')
# /var/folders/v6/yf2_m27929b9ms5vf1k6vvpw0000gn/T/ipykernel_16119/3566550557.py:35: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "bbox" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(f"radosbench_metal_{path}.pdf", bbox='tight')
# /var/folders/v6/yf2_m27929b9ms5vf1k6vvpw0000gn/T/ipykernel_16119/3566550557.py:35: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "bbox" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(f"radosbench_metal_{path}.pdf", bbox='tight')
# /var/folders/v6/yf2_m27929b9ms5vf1k6vvpw0000gn/T/ipykernel_16119/3566550557.py:35: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "bbox" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(f"radosbench_metal_{path}.pdf", bbox='tight')
# /var/folders/v6/yf2_m27929b9ms5vf1k6vvpw0000gn/T/ipykernel_16119/3566550557.py:35: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "bbox" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(f"radosbench_metal_{path}.pdf", bbox='tight')
# /var/folders/v6/yf2_m27929b9ms5vf1k6vvpw0000gn/T/ipykernel_16119/3566550557.py:35: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "bbox" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(f"radosbench_metal_{path}.pdf", bbox='tight')
# /var/folders/v6/yf2_m27929b9ms5vf1k6vvpw0000gn/T/ipykernel_16119/3566550557.py:35: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "bbox" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(f"radosbench_metal_{path}.pdf", bbox='tight')
# /var/folders/v6/yf2_m27929b9ms5vf1k6vvpw0000gn/T/ipykernel_16119/3566550557.py:35: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "bbox" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(f"radosbench_metal_{path}.pdf", bbox='tight')
# /var/folders/v6/yf2_m27929b9ms5vf1k6vvpw0000gn/T/ipykernel_16119/3566550557.py:35: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "bbox" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(f"radosbench_metal_{path}.pdf", bbox='tight')
# /var/folders/v6/yf2_m27929b9ms5vf1k6vvpw0000gn/T/ipykernel_16119/3566550557.py:35: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "bbox" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(f"radosbench_metal_{path}.pdf", bbox='tight')
# /var/folders/v6/yf2_m27929b9ms5vf1k6vvpw0000gn/T/ipykernel_16119/3566550557.py:35: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "bbox" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(f"radosbench_metal_{path}.pdf", bbox='tight')
# /var/folders/v6/yf2_m27929b9ms5vf1k6vvpw0000gn/T/ipykernel_16119/3566550557.py:35: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "bbox" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(f"radosbench_metal_{path}.pdf", bbox='tight')
# /var/folders/v6/yf2_m27929b9ms5vf1k6vvpw0000gn/T/ipykernel_16119/3566550557.py:35: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "bbox" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(f"radosbench_metal_{path}.pdf", bbox='tight')
# /var/folders/v6/yf2_m27929b9ms5vf1k6vvpw0000gn/T/ipykernel_16119/3566550557.py:35: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "bbox" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(f"radosbench_metal_{path}.pdf", bbox='tight')
# /var/folders/v6/yf2_m27929b9ms5vf1k6vvpw0000gn/T/ipykernel_16119/3566550557.py:35: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "bbox" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(f"radosbench_metal_{path}.pdf", bbox='tight')
# /var/folders/v6/yf2_m27929b9ms5vf1k6vvpw0000gn/T/ipykernel_16119/3566550557.py:35: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "bbox" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(f"radosbench_metal_{path}.pdf", bbox='tight')
# /var/folders/v6/yf2_m27929b9ms5vf1k6vvpw0000gn/T/ipykernel_16119/3566550557.py:35: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "bbox" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(f"radosbench_metal_{path}.pdf", bbox='tight')
# /var/folders/v6/yf2_m27929b9ms5vf1k6vvpw0000gn/T/ipykernel_16119/3566550557.py:35: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "bbox" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig(f"radosbench_metal_{path}.pdf", bbox='tight')
